# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings as wr
wr.filterwarnings(action="ignore")
wr.filterwarnings("ignore", category=UserWarning, module="matplotlib")
wr.filterwarnings("ignore", category=FutureWarning)
import mlflow
from mlflow.models import infer_signature
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression, ElasticNet
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, RobustScaler,  OneHotEncoder
from sklearn.base import BaseEstimator, ClassifierMixin, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, precision_recall_curve, confusion_matrix, classification_report, fbeta_score
import seaborn as sns
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, ADASYN, SVMSMOTE
from imblearn.combine import SMOTETomek
from imblearn.pipeline import Pipeline as ImbPipeline
from xgboost import XGBClassifier
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LeakyReLU
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn.compose import ColumnTransformer, make_column_selector as selector
from sklearn.pipeline import Pipeline as SkPipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import FunctionTransformer
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE

# %% [markdown]
# <div style="background-color:rgba(47, 83, 136, 0.75) ; border-radius: 10px; text-align: center; padding: 20px;">
#     <h1 style="color: white;">Carga de datos</h1>
# </div>

# %% [markdown]
# We are merging multiple datasets

# %%
account = pd.read_csv("data/Customer Profiles/account_activity.csv")
customer = pd.read_csv("data/Customer Profiles/customer_data.csv")
fraud = pd.read_csv("data/Fraudulent Patterns/fraud_indicators.csv")
suspision = pd.read_csv("data/Fraudulent Patterns/suspicious_activity.csv")
merchant = pd.read_csv("data/Merchant Information/merchant_data.csv")
tran_cat = pd.read_csv("data/Merchant Information/transaction_category_labels.csv")
amount = pd.read_csv("data/Transaction Amounts/amount_data.csv")
anamoly = pd.read_csv("data/Transaction Amounts/anomaly_scores.csv")
tran_data = pd.read_csv("data/Transaction Data/transaction_metadata.csv")
tran_rec = pd.read_csv("data/Transaction Data/transaction_records.csv")

data = [account,customer,fraud,suspision,merchant,tran_cat,amount,anamoly,tran_data,tran_rec]

for df in data:
    print(df.head())
# Out:
#    CustomerID  AccountBalance   LastLogin
# 0        1001     9507.272060  2022-01-01
# 1        1002     7408.704536  2022-01-02
# 2        1003     1715.321989  2022-01-03
# 3        1004     3101.509134  2022-01-04
# 4        1005     5405.766914  2022-01-05
#    CustomerID           Name  Age       Address
# 0        1001  Customer 1001   54  Address 1001
# 1        1002  Customer 1002   35  Address 1002
# 2        1003  Customer 1003   40  Address 1003
# 3        1004  Customer 1004   30  Address 1004
# 4        1005  Customer 1005   46  Address 1005
#    TransactionID  FraudIndicator
# 0              1               0
# 1              2               0
# 2              3               0
# 3              4               0
# 4              5               0
#    CustomerID  SuspiciousFlag
# 0        1001               0
# 1        1002               0
# 2        1003               0
# 3        1004               0
# 4        1005               0
# ...

# %%
costumer_data = pd.merge(customer, account, on='CustomerID')
costumer_data = pd.merge(costumer_data, suspision, on='CustomerID')
costumer_data
# Out:
#      CustomerID           Name  Age       Address  AccountBalance   LastLogin  \
# 0          1001  Customer 1001   54  Address 1001     9507.272060  2022-01-01
# 1          1002  Customer 1002   35  Address 1002     7408.704536  2022-01-02
# 2          1003  Customer 1003   40  Address 1003     1715.321989  2022-01-03
# 3          1004  Customer 1004   30  Address 1004     3101.509134  2022-01-04
# 4          1005  Customer 1005   46  Address 1005     5405.766914  2022-01-05
# ..          ...            ...  ...           ...             ...         ...
# 995        1996  Customer 1996   33  Address 1996     8523.485163  2024-09-22
# 996        1997  Customer 1997   58  Address 1997     9255.451757  2024-09-23
# 997        1998  Customer 1998   25  Address 1998     9148.652759  2024-09-24
# 998        1999  Customer 1999   57  Address 1999     7376.854107  2024-09-25
# 999        2000  Customer 2000   42  Address 2000     4853.024380  2024-09-26
#
#      SuspiciousFlag
# ...

# %%
transaction_data1 = pd.merge(fraud, tran_cat, on="TransactionID")
transaction_data2 = pd.merge(amount, anamoly, on="TransactionID")
transaction_data3 = pd.merge(tran_data, tran_rec, on="TransactionID")
transaction_data = pd.merge(transaction_data1, transaction_data2,on="TransactionID")
transaction_data = pd.merge(transaction_data, transaction_data3,on="TransactionID")
transaction_data
# Out:
#      TransactionID  FraudIndicator Category  TransactionAmount  AnomalyScore  \
# 0                1               0    Other          79.413607      0.686699
# 1                2               0   Online          12.053087      0.081749
# 2                3               0   Travel          33.310357      0.023857
# 3                4               0   Travel          46.121117      0.876994
# 4                5               0    Other          54.051618      0.034059
# ..             ...             ...      ...                ...           ...
# 995            996               0     Food          89.457059      0.266778
# 996            997               0   Retail          47.958030      0.512483
# 997            998               0     Food          64.210046      0.367740
# 998            999               0   Travel          64.684167      0.960364
# 999           1000               0    Other          97.440127      0.311224
#
# ...

# %%
data = pd.merge(transaction_data, costumer_data,on="CustomerID")
data
# Out:
#      TransactionID  FraudIndicator Category  TransactionAmount  AnomalyScore  \
# 0                1               0    Other          79.413607      0.686699
# 1                2               0   Online          12.053087      0.081749
# 2                3               0   Travel          33.310357      0.023857
# 3                4               0   Travel          46.121117      0.876994
# 4                5               0    Other          54.051618      0.034059
# ..             ...             ...      ...                ...           ...
# 995            996               0     Food          89.457059      0.266778
# 996            997               0   Retail          47.958030      0.512483
# 997            998               0     Food          64.210046      0.367740
# 998            999               0   Travel          64.684167      0.960364
# 999           1000               0    Other          97.440127      0.311224
#
# ...

# %% [markdown]
# <div style="background-color:rgba(47, 83, 136, 0.75) ; border-radius: 10px; text-align: center; padding: 20px;">
#     <h1 style="color: white;">Limpieza de datos</h1>
# </div>

# %%
# Verificación de valores nulos
data.dropna(inplace=True)
print("Verificando valores nulos por columna:")
print(data.isnull().sum())
print("\n")
# Out:
# Verificando valores nulos por columna:
# TransactionID        0
# FraudIndicator       0
# Category             0
# TransactionAmount    0
# AnomalyScore         0
# Timestamp            0
# MerchantID           0
# Amount               0
# CustomerID           0
# Name                 0
# Age                  0
# Address              0
# AccountBalance       0
# LastLogin            0
# SuspiciousFlag       0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
print("Número de filas duplicadas después de la limpieza:", data.duplicated().sum())
# Out:
# Número de filas duplicadas después de la limpieza: 0

# %%
# Conversión de tipos de datos 
# Las columnas 'Timestamp' y 'LastLogin' son de tipo 'object' pero representan fechas/horas.
print("Tipos de datos antes de la conversión:")
print(data[['Timestamp', 'LastLogin']].dtypes)

data['Timestamp'] = pd.to_datetime(data['Timestamp'])
data['LastLogin'] = pd.to_datetime(data['LastLogin'])

print("\nTipos de datos después de la conversión:")
print(data[['Timestamp', 'LastLogin']].dtypes)
print("\n")
# Out:
# Tipos de datos antes de la conversión:
# Timestamp    object
# LastLogin    object
# dtype: object
#
# Tipos de datos después de la conversión:
# Timestamp    datetime64[ns]
# LastLogin    datetime64[ns]
# dtype: object

# %% [markdown]
# <div style="background-color:rgba(47, 83, 136, 0.75) ; border-radius: 10px; text-align: center; padding: 20px;">
#     <h1 style="color: white;">Exploración de datos</h1>
# </div>

# %%
print(" Información general del dataset:")
data.info()

print("\n Dimensiones del dataset (filas, columnas):")
print(data.shape)

print("\n Estadísticas descriptivas del dataset:")
print(data.describe())
# Out:
#  Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      1000 non-null   int64
#  1   FraudIndicator     1000 non-null   int64
#  2   Category           1000 non-null   object
#  3   TransactionAmount  1000 non-null   float64
#  4   AnomalyScore       1000 non-null   float64
#  5   Timestamp          1000 non-null   datetime64[ns]
#  6   MerchantID         1000 non-null   int64
#  7   Amount             1000 non-null   float64
#  8   CustomerID         1000 non-null   int64
#  9   Name               1000 non-null   object
#  10  Age                1000 non-null   int64
#  11  Address            1000 non-null   object
#  12  AccountBalance     1000 non-null   float64
#  13  LastLogin          1000 non-null   datetime64[ns]
#  14  SuspiciousFlag     1000 non-null   int64
# ...

# %%
# Definición de columnas categóricas
categorical_columns = ["FraudIndicator", 'SuspiciousFlag', "Category", "Name", "Address", "LastLogin"]

# Definición de columnas numéricas
numeric_columns = ['TransactionID', 'TransactionAmount', 'AnomalyScore', 'MerchantID', 'Amount', 'CustomerID', 'Age', 'AccountBalance']

# %% [markdown]
# ## Countplot de variables categoricas

# %%
# Definir número de columnas y calcular filas necesarias
ncols = 3
nrows = (len(categorical_columns) + ncols - 1) // ncols

# Crear figura y ejes
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 4 * nrows))
axes = axes.flatten()

# Graficar cada variable
for idx, column in enumerate(categorical_columns):
    top_10_values = data[column].value_counts().head(10)
    sns.countplot(
        x=column,
        data=data,
        order=top_10_values.index,
        color="steelblue",
        edgecolor='black',
        ax=axes[idx]
    )
    axes[idx].set_title(f'Distribución de {column}', fontsize=13)
    axes[idx].set_xlabel(column, fontsize=13)
    axes[idx].set_ylabel('Frecuencia', fontsize=13)
    axes[idx].tick_params(axis='x', rotation=30, labelsize=11)
    axes[idx].tick_params(axis='y', labelsize=11)

# Eliminar subplots vacíos
for j in range(idx + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Histplot para variables numéricas

# %%
# Crear figura y subplots
fig, axes = plt.subplots(
    nrows=(len(numeric_columns) + 2) // 3,  
    ncols=3,
    figsize=(12, 9)
)

# Aplanar el array de ejes
axes = axes.flatten()

# Recorrer variables numéricas
for idx, column in enumerate(numeric_columns):
    sns.histplot(
        data[column], 
        kde=True, 
        color="steelblue",
        ax=axes[idx]  
    )
    axes[idx].set_title(f'Distribución de {column}', fontsize=13)
    axes[idx].set_xlabel(column, fontsize=12)
    axes[idx].set_ylabel('Frecuencia', fontsize=12)
    axes[idx].tick_params(axis='x', rotation=0)

# Eliminar subplots vacíos
for j in range(idx + 1, len(axes)):
    fig.delaxes(axes[j])

# Ajustar espacio
plt.tight_layout()
plt.show()

# %% [markdown]
# ## BoxPlot de variables numericas

# %%
num_cols = len(numeric_columns)

# Definir cantidad de filas y columnas
ncols = 3  
nrows = (num_cols + ncols - 1) // ncols 

# Crear figura y subplots
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, 5 * nrows))
axes = axes.flatten()  

# Dibujar los boxplots
for idx, column in enumerate(numeric_columns):
    sns.boxplot(
        x=data[column],
        color='skyblue',
        ax=axes[idx]
    )
    axes[idx].set_title(f'Boxplot de {column}', fontsize=14)
    axes[idx].set_xlabel(column, fontsize=12)
    axes[idx].set_ylabel('Valor', fontsize=12)

# Si sobran ejes vacíos, eliminarlos
for j in range(idx + 1, len(axes)):
    fig.delaxes(axes[j])

# Ajustes de espaciado
plt.tight_layout()
plt.subplots_adjust(top=0.92)
fig.suptitle('Boxplots de Variables Numéricas', fontsize=20)
plt.show()

# %% [markdown]
# ## Matriz de correlación a variables numericas

# %%
# Filtrar solo las columnas numéricas
numeric_df = data[numeric_columns]

# Calcular la matriz de correlación
correlation_matrix = numeric_df.corr()

# Crear el heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_matrix,
    annot=True,        
    cmap='coolwarm',     
    fmt=".2f",            
    linewidths=0.5,   
    linecolor='white',      
    square=True,          
    cbar_kws={"shrink": .8} 
)
plt.title('Matriz de Correlación entre Variables Numéricas', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right')  
plt.yticks(rotation=0)             
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:rgba(47, 83, 136, 0.75) ; border-radius: 10px; text-align: center; padding: 20px;">
#     <h1 style="color: white;">Feature Engineering</h1>
# </div>

# %% [markdown]
# <b> Feature Engineering consiste en seleccionar y transformar las variables que se utilizarán en el modelo. Tambien normalizar variables, manipular datos categóricos y crear nuevas variables a partir de las existentes </b>

# %%
# Eliminar las columnas a partir de ahora no están muy correlacionadas y tampoco afectaría el rendimiento del modelo.
columns_to_be_dropped = ['TransactionID','Name', 'Age', 'Address']
data1 = data.drop(columns_to_be_dropped, axis=1)
data1.head()
# Out:
#    FraudIndicator Category  TransactionAmount  AnomalyScore  \
# 0               0    Other          79.413607      0.686699
# 1               0   Online          12.053087      0.081749
# 2               0   Travel          33.310357      0.023857
# 3               0   Travel          46.121117      0.876994
# 4               0    Other          54.051618      0.034059
#
#             Timestamp  MerchantID     Amount  CustomerID  AccountBalance  \
# 0 2022-01-01 00:00:00        2701  55.530334        1952     2869.689912
# 1 2022-01-01 01:00:00        2070  12.881180        1027     9527.947107
# 2 2022-01-01 02:00:00        2238  50.176322        1955     9288.355525
# 3 2022-01-01 03:00:00        2879  41.634001        1796     5588.049942
# 4 2022-01-01 04:00:00        2966  78.122853        1946     7324.785332
#
#    LastLogin  SuspiciousFlag
# 0 2024-08-09               0
# 1 2022-01-27               0
# 2 2024-08-12               0
# 3 2024-03-06               0
# ...

# %%
data1['FraudIndicator'].value_counts(), data1['SuspiciousFlag'].value_counts(), data1['Category'].value_counts()
# Out:
# (FraudIndicator
#  0    955
#  1     45
#  Name: count, dtype: int64,
#  SuspiciousFlag
#  0    975
#  1     25
#  Name: count, dtype: int64,
#  Category
#  Other     210
#  Food      204
#  Travel    198
#  Online    196
#  Retail    192
#  Name: count, dtype: int64)

# %%
# Using Feature Engineering Creating two Columns
# Hour of Transaction = hour
# Gap between the day of transaction and last login in days = gap
from sklearn.preprocessing import OneHotEncoder

data1['Hour'] = data1['Timestamp'].dt.hour
data1['gap'] = (data1['Timestamp'] - data1['LastLogin']).dt.days.abs()
data1['DayOfWeek'] = data1['Timestamp'].dt.dayofweek
data1['Month'] = data1['Timestamp'].dt.month
data1['IsWeekend'] = data1['DayOfWeek'].isin([5, 6]).astype(int)

# Proporción del monto sobre el saldo
data1['TransactionAmountRelativeToBalance'] = data1['TransactionAmount'] / data1['AccountBalance']
data1['TransactionAmountRelativeToBalance'].replace([np.inf, -np.inf], np.nan, inplace=True)
data1['TransactionAmountRelativeToBalance'].fillna(0, inplace=True)
data1['IsHighAmount'] = (data1['TransactionAmount'] > data1['TransactionAmount'].quantile(0.75)).astype(int)

# 1. Frecuencia de transacciones
freq_customer = data1['CustomerID'].value_counts().to_dict()
data1['CustomerTransactionFreq'] = data1['CustomerID'].map(freq_customer)


# 3. Score promedio de anomalía por cliente/comercio
avg_anomaly_customer = data1.groupby('CustomerID')['AnomalyScore'].mean().to_dict()
data1['CustomerAvgAnomaly'] = data1['CustomerID'].map(avg_anomaly_customer)

# Mapas por CustomerID
freq_map_ = data1['CustomerID'].value_counts().to_dict()
mean_map_ = data1.groupby('CustomerID')['AnomalyScore'].mean().to_dict()
global_mean_ = float(data1['AnomalyScore'].mean())

data1['CustomerTransactionFreq'] = data1['CustomerID'].map(freq_map_).fillna(0).astype(int)
data1['CustomerAvgAnomaly'] = data1['CustomerID'].map(mean_map_).fillna(global_mean_)


denom = data1['AccountBalance'].replace(0, np.nan)
data1['TransactionAmountRelativeToBalance'] = (data1['TransactionAmount'] / denom).fillna(0)

# Flag de monto alto
high_amount_thr_ = data1['TransactionAmount'].quantile(0.75)
data1['IsHighAmount'] = (data1['TransactionAmount'] > high_amount_thr_).astype(int)

# Interacciones simples
data1['Amount_x_Anomaly'] = data1['TransactionAmount'] * data1['AnomalyScore']
data1['Gap_x_Amount'] = data1['gap'] * data1['TransactionAmount']
data1['AmountRel_x_IsWeekend'] = data1['TransactionAmountRelativeToBalance'] * data1['IsWeekend']


label_encoder = LabelEncoder()
data1['Category'] = label_encoder.fit_transform(data1['Category'])


data1.head()
# Out:
#    FraudIndicator  Category  TransactionAmount  AnomalyScore  \
# 0               0         2          79.413607      0.686699
# 1               0         1          12.053087      0.081749
# 2               0         4          33.310357      0.023857
# 3               0         4          46.121117      0.876994
# 4               0         2          54.051618      0.034059
#
#             Timestamp  MerchantID     Amount  CustomerID  AccountBalance  \
# 0 2022-01-01 00:00:00        2701  55.530334        1952     2869.689912
# 1 2022-01-01 01:00:00        2070  12.881180        1027     9527.947107
# 2 2022-01-01 02:00:00        2238  50.176322        1955     9288.355525
# 3 2022-01-01 03:00:00        2879  41.634001        1796     5588.049942
# 4 2022-01-01 04:00:00        2966  78.122853        1946     7324.785332
#
#    LastLogin  ...  DayOfWeek  Month  IsWeekend  \
# 0 2024-08-09  ...          5      1          1
# 1 2022-01-27  ...          5      1          1
# ...

# %%
# Se eliminan las columnas que no son relevantes y se separa la variable objetivo en la variable Y
x_data = data1.drop(['FraudIndicator','Timestamp','LastLogin', 'CustomerID', 'MerchantID'],axis=1)
x_data_raw = data.drop(['FraudIndicator'],axis=1)
y_data = data1['FraudIndicator']

# %% [markdown]
# Definición de clases para su uso posterior en los pipelines de los modelos:

# %%
# --- 0) Agrupador de categorías raras (antes del OHE) ---
class RareCategoryGrouper(BaseEstimator, TransformerMixin):
    def __init__(self, col='Category', min_freq=20, other_label='__OTHER__'):
        self.col = col
        self.min_freq = min_freq
        self.other_label = other_label
        self.keep_ = None

    def fit(self, X, y=None):
        X_ = X if isinstance(X, pd.DataFrame) else pd.DataFrame(X)
        if self.col in X_.columns:
            vc = X_[self.col].astype('string').value_counts()
            self.keep_ = set(vc[vc >= self.min_freq].index)
        else:
            self.keep_ = None
        return self

    def transform(self, X):
        X = X.copy()
        if self.keep_ is not None and self.col in X.columns:
            X[self.col] = X[self.col].astype('string')
            mask = ~X[self.col].isin(self.keep_)
            X.loc[mask, self.col] = self.other_label
        return X


# --- 1) Feature engineering robusto ---
class FeatureEngineer(BaseEstimator, TransformerMixin):
    """
    Crea columnas derivadas SIN fuga:
    - Extrae Hour, DayOfWeek, Month, IsWeekend + codificación cíclica de Hour
    - gap en días (Timestamp - LastLogin)
    - TransactionAmountRelativeToBalance (seguro a /0)
    - IsHighAmount con umbral aprendido en fit (percentil configurable)
    - Interacciones simples
    - Asegura tipo string en Category (para OHE posterior)
    """
    def __init__(self,
                 columns_to_drop=None,
                 ts_col='Timestamp',
                 last_login_col='LastLogin',
                 amount_col='TransactionAmount',
                 balance_col='AccountBalance',
                 category_col='Category',
                 high_amount_q=0.75,
                 add_hour_cyc=True,
                 night_hours=(0,6)  # [0,6) = noche
                 ):
        self.columns_to_drop = columns_to_drop or []
        self.ts_col = ts_col
        self.last_login_col = last_login_col
        self.amount_col = amount_col
        self.balance_col = balance_col
        self.category_col = category_col
        self.high_amount_q = high_amount_q
        self.add_hour_cyc = add_hour_cyc
        self.night_hours = night_hours
        self.high_amount_thr_ = None

    def fit(self, X, y=None):
        X_ = X.copy()
        for c in [self.ts_col, self.last_login_col]:
            if c in X_.columns:
                X_[c] = pd.to_datetime(X_[c], errors='coerce')
        if self.amount_col in X_.columns:
            self.high_amount_thr_ = X_[self.amount_col].quantile(self.high_amount_q)
        return self

    def transform(self, X):
        X = X.copy()

        # Drop crudo
        to_drop = [c for c in self.columns_to_drop if c in X.columns]
        if to_drop:
            X.drop(columns=to_drop, inplace=True, errors='ignore')

        # Asegurar datetime
        if self.ts_col in X.columns:
            X[self.ts_col] = pd.to_datetime(X[self.ts_col], errors='coerce')
        if self.last_login_col in X.columns:
            X[self.last_login_col] = pd.to_datetime(X[self.last_login_col], errors='coerce')

        # Derivadas temporales
        if self.ts_col in X.columns:
            ts = X[self.ts_col]
            X['Hour'] = ts.dt.hour
            X['DayOfWeek'] = ts.dt.dayofweek
            X['Month'] = ts.dt.month
            X['IsWeekend'] = X['DayOfWeek'].isin([5, 6]).astype(int)

            if self.add_hour_cyc:
                # Codificación cíclica para capturar periodicidad
                X['Hour_sin'] = np.sin(2*np.pi*X['Hour']/24.0)
                X['Hour_cos'] = np.cos(2*np.pi*X['Hour']/24.0)

            if self.night_hours:
                h0, h1 = self.night_hours
                X['IsNight'] = X['Hour'].between(h0, h1-1, inclusive='both').astype(int)

        # Gap en días
        if self.ts_col in X.columns and self.last_login_col in X.columns:
            delta = (X[self.ts_col] - X[self.last_login_col])
            X['gap'] = delta.dt.days.abs()

        # Proporción monto/saldo (segura)
        if self.amount_col in X.columns and self.balance_col in X.columns:
            denom = X[self.balance_col].replace([0, np.inf, -np.inf], np.nan)
            ratio = np.divide(X[self.amount_col], denom)
            ratio = np.where(np.isfinite(ratio), ratio, np.nan)
            X['TransactionAmountRelativeToBalance'] = pd.Series(ratio).fillna(0)

        # Flag de monto alto con umbral aprendido en fit
        if self.high_amount_thr_ is not None and self.amount_col in X.columns:
            X['IsHighAmount'] = (X[self.amount_col] > self.high_amount_thr_).astype(int)

        # Interacciones simples
        if all(c in X.columns for c in [self.amount_col, 'AnomalyScore']):
            X['Amount_x_Anomaly'] = X[self.amount_col] * X['AnomalyScore']
        if all(c in X.columns for c in ['gap', self.amount_col]):
            X['Gap_x_Amount'] = X['gap'] * X[self.amount_col]
        if all(c in X.columns for c in ['TransactionAmountRelativeToBalance', 'IsWeekend']):
            X['AmountRel_x_IsWeekend'] = X['TransactionAmountRelativeToBalance'] * X['IsWeekend']

        # Category como string
        if self.category_col in X.columns:
            X[self.category_col] = X[self.category_col].astype('string')

        return X


# --- 2) Agregados por ID con suavizado (m-estimate) ---
class GroupStatsByID(BaseEstimator, TransformerMixin):
    """
    - Frecuencia por ID
    - Promedio de AnomalyScore por ID con suavizado m (para IDs con pocos ejemplos)
    Evita fuga: mapas aprendidos SOLO en fit (fold de train).
    """
    def __init__(self, id_col='CustomerID', score_col='AnomalyScore', m=5.0):
        self.id_col = id_col
        self.score_col = score_col
        self.m = m
        self.freq_map_ = None
        self.mean_map_ = None
        self.global_mean_ = None
        self.count_map_ = None

    def fit(self, X, y=None):
        X_ = X.copy()
        if self.id_col in X_.columns:
            counts = X_[self.id_col].value_counts()
            self.freq_map_ = counts.to_dict()
            self.count_map_ = counts.to_dict()
        if self.id_col in X_.columns and self.score_col in X_.columns:
            means = X_.groupby(self.id_col)[self.score_col].mean()
            self.mean_map_ = means.to_dict()
            self.global_mean_ = float(X_[self.score_col].mean())
        return self

    def transform(self, X):
        X = X.copy()
        if self.id_col in X.columns:
            # Frecuencia
            X['CustomerTransactionFreq'] = X[self.id_col].map(self.freq_map_).fillna(0).astype(int)
            # Promedio suavizado
            if self.mean_map_ is not None:
                mu = self.global_mean_
                n = X[self.id_col].map(self.count_map_).fillna(0)
                raw_mean = X[self.id_col].map(self.mean_map_).fillna(mu)
                # m-estimate: (n*mean + m*global) / (n + m)
                X['CustomerAvgAnomaly'] = ((n * raw_mean) + (self.m * mu)) / (n + self.m + 1e-9)
        return X

pre = ColumnTransformer(
    transformers=[
        # Numéricas: imputar medianas
        ('num', SkPipeline([
            ('imp', SimpleImputer(strategy='median')),
            ('sc', MinMaxScaler())
        ]), selector(dtype_include=['number'])),

        # Categóricas: imputar más frecuente + OHE
        ('cat', SkPipeline([
            ('imp', SimpleImputer(strategy='most_frequent')),
            ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False)),
        ]), selector(dtype_include=['object','string','category'])),
    ],
    remainder='drop'
)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import numpy as np, pandas as pd

class HistoryByID(BaseEstimator, TransformerMixin):
    def __init__(self, id_col='CustomerID', ts_col='Timestamp',
                 amount_col='TransactionAmount', y_col='__target__',
                 m=10.0, prefix='cust'):
        self.id_col=id_col; self.ts_col=ts_col; self.amount_col=amount_col
        self.y_col=y_col; self.m=m; self.prefix=prefix
        self.stats_=None  # df con agregados SOLO de train

    def fit(self, X, y=None):
        X_ = X.copy()
        if self.ts_col in X_.columns:
            X_[self.ts_col] = pd.to_datetime(X_[self.ts_col], errors='coerce')
        # y puede venir por argumento
        if y is not None and self.y_col not in X_.columns:
            X_[self.y_col] = y
        # agregados SOLO en train
        grp = X_.groupby(self.id_col, dropna=False)
        cnt = grp.size().rename(f'{self.prefix}_cnt_hist')
        mean = grp[self.amount_col].mean().rename(f'{self.prefix}_amt_mean_hist')
        std = grp[self.amount_col].std(ddof=0).fillna(0.).rename(f'{self.prefix}_amt_std_hist')
        last_ts = grp[self.ts_col].max().rename(f'{self.prefix}_last_ts_hist')

        # tasa de fraude suavizada m-estimate
        if self.y_col in X_.columns:
            mean_y = grp[self.y_col].mean()
            global_mean = float(X_[self.y_col].mean())
            n = cnt
            fraud_rate = ((n*mean_y) + (self.m*global_mean)) / (n + self.m)
            fraud_rate = fraud_rate.rename(f'{self.prefix}_fraud_rate_hist')
        else:
            fraud_rate = pd.Series(dtype=float, name=f'{self.prefix}_fraud_rate_hist')

        self.stats_ = pd.concat([cnt, mean, std, last_ts, fraud_rate], axis=1)
        return self

    def transform(self, X):
        X = X.copy()
        if self.ts_col in X.columns:
            X[self.ts_col] = pd.to_datetime(X[self.ts_col], errors='coerce')
        out = X.merge(self.stats_, left_on=self.id_col, right_index=True, how='left')

        # gap a último timestamp histórico (solo info de TRAIN)
        if f'{self.prefix}_last_ts_hist' in out.columns and self.ts_col in out.columns:
            gap = (out[self.ts_col] - out[f'{self.prefix}_last_ts_hist']).dt.days
            out[f'{self.prefix}_last_ts_gap_days'] = gap.fillna(9999).clip(lower=0)
        # z-score vs historia
        mu = out.get(f'{self.prefix}_amt_mean_hist')
        sd = out.get(f'{self.prefix}_amt_std_hist').replace(0, np.nan)
        if mu is not None and sd is not None:
            z = (out[self.amount_col] - mu) / sd
            out[f'{self.prefix}_amt_z_hist'] = z.replace([np.inf,-np.inf], np.nan).fillna(0)
        return out

# %%
class PairHistory(BaseEstimator, TransformerMixin):
    def __init__(self, cust_col='CustomerID', merch_col='MerchantID',
                 ts_col='Timestamp', prefix='pair'):
        self.cust_col=cust_col; self.merch_col=merch_col
        self.ts_col=ts_col; self.prefix=prefix
        self.stats_=None

    def fit(self, X, y=None):
        X_ = X.copy()
        X_[self.ts_col] = pd.to_datetime(X_[self.ts_col], errors='coerce')
        key = [self.cust_col, self.merch_col]
        grp = X_.groupby(key, dropna=False)
        cnt = grp.size().rename(f'{self.prefix}_cnt_hist')
        last_ts = grp[self.ts_col].max().rename(f'{self.prefix}_last_ts_hist')
        self.stats_ = pd.concat([cnt, last_ts], axis=1).reset_index()
        return self

    def transform(self, X):
        X = X.copy()
        X[self.ts_col] = pd.to_datetime(X[self.ts_col], errors='coerce')
        key = [self.cust_col, self.merch_col]
        out = X.merge(self.stats_, on=key, how='left')
        out[f'{self.prefix}_cnt_hist'] = out[f'{self.prefix}_cnt_hist'].fillna(0).astype(int)
        out[f'{self.prefix}_is_new'] = (out[f'{self.prefix}_cnt_hist'] == 0).astype(int)
        if f'{self.prefix}_last_ts_hist' in out.columns:
            gap = (out[self.ts_col] - out[f'{self.prefix}_last_ts_hist']).dt.days
            out[f'{self.prefix}_last_ts_gap_days'] = gap.fillna(9999).clip(lower=0)
        return out

# %%
class TargetMeanEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, col, y_col='__target__', m=10.0, out_col=None):
        self.col=col; self.y_col=y_col; self.m=m; self.out_col=out_col or f'{col}_te'
        self.map_=None; self.global_=None

    def fit(self, X, y=None):
        X_ = X.copy()
        if y is not None and self.y_col not in X_.columns:
            X_[self.y_col] = y
        self.global_ = float(X_[self.y_col].mean())
        stats = X_.groupby(self.col)[self.y_col].agg(['mean','count'])
        self.map_ = ((stats['mean']*stats['count'] + self.m*self.global_) / (stats['count']+self.m)).to_dict()
        return self

    def transform(self, X):
        X = X.copy()
        X[self.out_col] = X[self.col].map(self.map_).fillna(self.global_)
        return X

# %%
# Validacion de FE
rcg = RareCategoryGrouper(col='Category', min_freq=20)
fe  = FeatureEngineer(
    columns_to_drop=['TransactionID','Name','Age','Address'],
    ts_col='Timestamp', last_login_col='LastLogin',
    amount_col='TransactionAmount', balance_col='AccountBalance',
    category_col='Category', high_amount_q=0.75,
    add_hour_cyc=True, night_hours=(0,6)
)
gs  = GroupStatsByID(id_col='CustomerID', score_col='AnomalyScore', m=5.0)

df_step1 = rcg.fit_transform(x_data_raw)
df_step2 = fe.fit_transform(df_step1)
df_step3 = gs.fit_transform(df_step2)
df_step4 = pre.fit_transform(df_step3)
print(df_step3)
# Out:
#     Category  TransactionAmount  AnomalyScore           Timestamp  MerchantID  \
# 0      Other          79.413607      0.686699 2022-01-01 00:00:00        2701
# 1     Online          12.053087      0.081749 2022-01-01 01:00:00        2070
# 2     Travel          33.310357      0.023857 2022-01-01 02:00:00        2238
# 3     Travel          46.121117      0.876994 2022-01-01 03:00:00        2879
# 4      Other          54.051618      0.034059 2022-01-01 04:00:00        2966
# ..       ...                ...           ...                 ...         ...
# 995     Food          89.457059      0.266778 2022-02-11 11:00:00        2150
# 996   Retail          47.958030      0.512483 2022-02-11 12:00:00        2888
# 997     Food          64.210046      0.367740 2022-02-11 13:00:00        2037
# 998   Travel          64.684167      0.960364 2022-02-11 14:00:00        2629
# 999    Other          97.440127      0.311224 2022-02-11 15:00:00        2235
#
# ...

# %% [markdown]
# <div style="background-color:rgba(47, 83, 136, 0.75) ; border-radius: 10px; text-align: center; padding: 20px;">
#     <h1 style="color: white;">Normalización de datos</h1>
# </div>

# %%
def normalizar_datos(x):
    # Columnas a escalar
    cols_to_scale = ['TransactionAmount', 'Amount', 'AccountBalance', 'gap']

    # Inicializar el scaler
    scaler = StandardScaler()

    # Ajustar el scaler y transformar los datos
    x[cols_to_scale] = scaler.fit_transform(x[cols_to_scale])

    return x

# %% [markdown]
# <div style="background-color:rgba(47, 83, 136, 0.75) ; border-radius: 10px; text-align: center; padding: 20px;">
#     <h1 style="color: white;">Sobremuestreo de datos</h1>
# </div>

# %%
def sobremuestreo_de_datos(x, y):
    # Initialize SMOTE for oversampling
    smote = SMOTE(random_state=42)

    # Apply SMOTE to the data
    x_resampled, y_resampled = smote.fit_resample(x, y)

    return x_resampled, y_resampled

# %% [markdown]
# <div style="background-color:rgba(47, 83, 136, 0.75) ; border-radius: 10px; text-align: center; padding: 20px;">
#     <h1 style="color: white;">Modelado de datos</h1>
# </div>

# %% [markdown]
# Definición de métricas que se usaran para evaluar modelos

# %%
scoring = {
    'acc': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score),
    'recall': make_scorer(recall_score),
    'f1': make_scorer(f1_score),
    'auc': make_scorer(roc_auc_score),
    'auprc': 'average_precision',
}

# %% [markdown]
# ### Regresión logística

# %% [markdown]
# #### Definicion de configuraciones y parametros

# %%
param_grid_lr_1 = [
    # SMOTE y SVMSMOTE, con l2
    {
        'clf__penalty': ['l2'],
        'clf__C': [0.01, 0.1, 1.0, 10.0],
        'clf__solver': ['lbfgs', 'saga'],
        'clf__class_weight': ['balanced'],
        'clf__max_iter': [100],
        'clf__fit_intercept': [True],
        'clf__tol': [0.001],
        'scaler': [MinMaxScaler(), RobustScaler(), StandardScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [SMOTE(), SVMSMOTE()],
        'smote__k_neighbors': [3, 5, 7],
        'smote__sampling_strategy': ['auto', 0.8],
        'smote__random_state': [42]
    },
    # ADASYN con l1
    {
        'clf__penalty': ['l1'],
        'clf__C': [0.01, 0.1, 1.0, 10.0],
        'clf__solver': ['liblinear'], 
        'clf__class_weight': ['balanced'],
        'clf__max_iter': [100],
        'clf__fit_intercept': [True],
        'clf__tol': [0.001],
        'scaler': [MinMaxScaler(), RobustScaler(), StandardScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [ADASYN()],
        'smote__n_neighbors': [3, 5, 7],
        'smote__sampling_strategy': ['auto', 0.8],
        'smote__random_state': [42]
    }
]

param_grid_lr_2 = [
    # --- L2 ---
    {
        'clf__penalty': ['l2'],
        'clf__C': [0.001, 0.005, 0.01, 0.1],
        'clf__solver': ['lbfgs', 'sag', 'newton-cg', 'saga', 'liblinear'],
        'clf__class_weight': ['balanced', {0:1, 1:3}, {0:1, 1:2}],
        'clf__max_iter': [100, 300],
        'clf__fit_intercept': [True, False],
        'clf__tol': [0.0001, 0.001],
        'clf__warm_start': [False, True],
        'scaler': [MinMaxScaler(),RobustScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.3, random_state=42),
                  RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [SMOTE()],
        'smote__k_neighbors': [3, 5],
        'smote__sampling_strategy': ['auto'],
        'smote__random_state': [42]
    },

    # --- L1 ---
    {
        'clf__penalty': ['l1'],
        'clf__C': [0.001, 0.005, 0.01, 0.1],
        'clf__solver': ['liblinear', 'saga'],
        'clf__class_weight': ['balanced', {0:1, 1:3}, {0:1, 1:2}],
        'clf__max_iter': [100, 300],
        'clf__fit_intercept': [True],
        'clf__tol': [0.0001, 0.001],
        'clf__warm_start': [False, True],
        'clf__dual': [False],  
        'scaler': [MinMaxScaler(),RobustScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.3, random_state=42),RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [ADASYN()],
        'smote__n_neighbors': [3, 5],
        'smote__sampling_strategy': ['auto'],
        'smote__random_state': [42]
    },

    # --- ElasticNet ---
    {
        'clf__penalty': ['elasticnet'],
        'clf__C': [0.01, 0.1, 1.0],
        'clf__solver': ['saga'],
        'clf__class_weight': ['balanced', {0:1, 1:3}, {0:1, 1:2}],
        'clf__l1_ratio': [0.25, 0.5, 0.75],  
        'clf__max_iter': [100, 300],
        'clf__fit_intercept': [True],
        'clf__tol': [0.0001, 0.001],
        'clf__warm_start': [False, True],
        'scaler': [MinMaxScaler(),RobustScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.3, random_state=42),RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [SMOTE()],
        'smote__k_neighbors': [3, 5],
        'smote__sampling_strategy': ['auto'],
        'smote__random_state': [42]
    }
]

param_grid_lr_3 = [
    # --- L2 ---
    {
        'clf__penalty': ['l2'],
        'clf__C': [0.0005, 0.001, 0.005, 0.01, 0.05],
        'clf__solver': ['lbfgs', 'sag', 'saga', 'liblinear'],
        'clf__class_weight': ['balanced',{0: 1, 1: 1.5},{0: 1, 1: 1.75},{0: 1, 1: 2.0}],
        'clf__max_iter': [100, 200, 300],
        'clf__fit_intercept': [True],
        'clf__tol': [0.0001, 0.001],
        'clf__warm_start': [True],
        'scaler': [RobustScaler()],
        'smote': [SMOTE()],
        'smote__k_neighbors': [4, 5, 6],
        'smote__sampling_strategy': ['auto'],
        'smote__random_state': [42]
    },

    # --- ElasticNet ---
    {
        'clf__penalty': ['elasticnet'],
        'clf__C': [0.8, 0.9, 1.0],
        'clf__solver': ['saga'],
        'clf__class_weight': [{0: 1, 1: 1.5},{0: 1, 1: 1.75},{0: 1, 1: 1.9},{0: 1, 1: 2.0},{0: 1, 1: 2.1},{0: 1, 1: 2.25},{0: 1, 1: 2.5}],
        'clf__l1_ratio': [0.25, 0.5, 0.75],  
        'clf__max_iter': [100, 300],
        'clf__fit_intercept': [True],
        'clf__tol': [0.0001, 0.001],
        'clf__warm_start': [True],
        'scaler': [MinMaxScaler(),RobustScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.3, random_state=42),RandomUnderSampler(sampling_strategy=0.4, random_state=42),RandomUnderSampler(sampling_strategy=0.5, random_state=42)],
        'smote': [SMOTE()],
        'smote__k_neighbors': [2, 3, 4],
        'smote__sampling_strategy': ['auto'],
        'smote__random_state': [42]
    }
]


param_grid_lr_4 = [
    {
        'clf__penalty': ['elasticnet'],
        'clf__solver': ['saga'],
        'clf__C': [0.01, 0.1],
        'clf__l1_ratio': [0.75, 0.9, 1],
        'clf__class_weight': [{0: 1, 1: 1.5},{0: 1, 1: 1.75},{0: 1, 1: 1.9},{0: 1, 1: 2.0}],
        'clf__max_iter': [300],
        'clf__warm_start': [True],
        'clf__fit_intercept': [True],
        'clf__tol': [0.0001],
        'scaler': [MinMaxScaler(),RobustScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.2, random_state=42), RandomUnderSampler(sampling_strategy=0.3, random_state=42),RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [
            SMOTE(k_neighbors=2, sampling_strategy='auto', random_state=42),
            SMOTE(k_neighbors=3, sampling_strategy='auto', random_state=42),
            SMOTE(k_neighbors=4, sampling_strategy='auto', random_state=42),
            SMOTETomek(smote=SMOTE(k_neighbors=3, sampling_strategy='auto', random_state=42), random_state=42)
        ]
    }
]

param_grid_lr_5 = [
    {
        'clf__penalty': ['elasticnet'],
        'clf__C': [1.0],
        'clf__solver': ['saga'],
        'clf__class_weight': [{0: 1, 1: 1.75}],
        'clf__l1_ratio': [0.25],  
        'clf__max_iter': [100, 300],
        'clf__fit_intercept': [True],
        'clf__tol': [0.0001, 0.001],
        'clf__warm_start': [True],
        'scaler': [MinMaxScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [SMOTE()],
        'smote__k_neighbors': [2, 3, 4],
        'smote__sampling_strategy': ['auto'],
        'smote__random_state': [42]
    }
]

param_grid_lr_6 = [
    {
        'clf__penalty': ['elasticnet'],
        'clf__C': [1.0],
        'clf__solver': ['saga'],
        'clf__class_weight': [{0: 1, 1: 1.75}],
        'clf__l1_ratio': [0.25],  
        'clf__max_iter': [300, 500],
        'clf__fit_intercept': [True],
        'clf__tol': [0.0001, 0.001],
        'clf__warm_start': [True],
        'scaler': [MinMaxScaler()],
        'under': [RandomUnderSampler(sampling_strategy=0.4, random_state=42)],
        'smote': [SMOTE()],
        'smote__k_neighbors': [4,5],
        'smote__sampling_strategy': ['auto'],
        'smote__random_state': [42]
    }
]

# %% [markdown]
# #### Entraneminto y evaluación

# %%
pipeline_lr = Pipeline([
    ('under', RandomUnderSampler(sampling_strategy=0.3, random_state=42)),
    ('smote', ADASYN()),
    ('scaler', RobustScaler()), 
    ('clf', LogisticRegression(max_iter=500, random_state=42)) 
])

grid_search_lr = GridSearchCV(
    estimator=pipeline_lr,
    param_grid=param_grid_lr_6,
    scoring=scoring,
    refit='auc',  
    cv= StratifiedKFold(n_splits=4, shuffle=True, random_state=42),
    verbose=2,
    n_jobs=-1,
    return_train_score=True
)
grid_result_lr = grid_search_lr.fit(x_data, y_data)


print("Mejor modelo:", grid_result_lr.best_estimator_)
print("Mejores parámetros:", grid_result_lr.best_params_)
print("Mejor AUC:", grid_result_lr.best_score_)

# Exportar resultados
results_df = pd.DataFrame(grid_result_lr.cv_results_)
results_df.to_csv("resultados/logistic_gridsearch_results.csv", index=False, sep='|', decimal=',')
# Out:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
# Mejor modelo: Pipeline(steps=[('under',
#                  RandomUnderSampler(random_state=42, sampling_strategy=0.4)),
#                 ('smote', SMOTE(k_neighbors=4, random_state=42)),
#                 ('scaler', MinMaxScaler()),
#                 ('clf',
#                  LogisticRegression(class_weight={0: 1, 1: 1.75}, l1_ratio=0.25,
#                                     max_iter=300, penalty='elasticnet',
#                                     random_state=42, solver='saga',
#                                     warm_start=True))])
# ...

# %%
results_df.to_csv("resultados/logistic_gridsearch_results_.csv")

# %% [markdown]
# #### Ajuste del Umbral de Clasificación

# %%
# Después del fit
best_estimator = grid_result_lr.best_estimator_
y_scores = best_estimator.predict_proba(x_data)[:, 1]
prec, rec, thresholds = precision_recall_curve(y_data, y_scores)

# Plot para elegir punto de corte
import matplotlib.pyplot as plt
plt.plot(thresholds, prec[:-1], label='Precision')
plt.plot(thresholds, rec[:-1], label='Recall')
plt.xlabel('Threshold')
plt.legend()
plt.grid()
plt.show()

# %%
# Obtener el mejor pipeline entrenado
best_pipeline = grid_result_lr.best_estimator_

y_proba = best_pipeline.predict_proba(x_data)[:, 1]  # Probabilidad de clase 1
+96
y_pred = (y_proba >= 0.3).astype(int)

print("Matriz de confusión:\n", confusion_matrix(y_data, y_pred))
print("\nReporte de clasificación:\n", classification_report(y_data, y_pred, digits=4))
print("AUC:", roc_auc_score(y_data, y_proba))


# Calcula la curva ROC
fpr, tpr, thresholds = roc_curve(y_data, y_proba)
roc_auc = auc(fpr, tpr)

# Plot
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Matriz de confusión:
#  [[132 823]
#  [  4  41]]
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0     0.9706    0.1382    0.2420       955
#            1     0.0475    0.9111    0.0902        45
#
#     accuracy                         0.1730      1000
#    macro avg     0.5090    0.5247    0.1661      1000
# weighted avg     0.9290    0.1730    0.2352      1000
#
# AUC: 0.6490750436300176

# %% [markdown]
# #### Validacion de importancia de variables

# %% [markdown]
# El valor del coeficiente indica cuánto y en qué dirección influye esa variable en la probabilidad de que la transacción sea fraudulenta (FraudIndicator = 1)

# %%
import matplotlib.pyplot as plt
import numpy as np

best_pipeline = grid_search_lr.best_estimator_

# Obtener los coeficientes del modelo (es un array 2D, tomamos la fila 0)
coefs = best_pipeline.named_steps['clf'].coef_[0]
features = best_pipeline.named_steps['scaler'].get_feature_names_out(x_data.columns)

# Ordenarlos por magnitud absoluta
sorted_idx = np.argsort(np.abs(coefs))

plt.figure(figsize=(6, 6))
plt.barh(range(len(features)), coefs[sorted_idx], color='skyblue')
plt.yticks(range(len(features)), features[sorted_idx])
plt.xlabel("Coeficiente")
plt.title("Importancia de las variables - Regresión Logística")
plt.axvline(x=0, color='gray', linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### XGBoost

# %% [markdown]
# #### Definición de configuraciones y parametros

# %%
# Calcula el peso
counts = Counter(y_data)
neg, pos = counts[0], counts[1]
ratio = neg / pos

param_grid_xgb_1 = {
    #'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler()],
    #'smt': [SMOTE(random_state=42), SVMSMOTE(random_state=42), ADASYN(random_state=42), SMOTETomek(random_state=42)],
    'xgb__n_estimators': [200, 300],
    'xgb__learning_rate': [0.01, 0.05],
    'xgb__max_depth': [4, 6],
    'xgb__subsample': [0.8, 1.0],
    'xgb__colsample_bytree': [0.8, 1.0],
    'xgb__scale_pos_weight': [ratio/2, ratio, ratio*2],
    'xgb__gamma':               [0, 0.1, 0.2],
    'xgb__reg_alpha':           [0.0, 0.01, 0.1],
    'xgb__reg_lambda':          [0.5, 1.0, 1.5],
    'xgb__min_child_weight':    [1, 3, 5],
}

param_grid_xgb_2 = {
    'xgb__n_estimators':        [150, 200, 250], 
    'xgb__max_depth':           [5, 6, 7],
    'xgb__learning_rate':       [0.005, 0.01, 0.02],
    'xgb__subsample':           [0.8, 1.0],
    'xgb__colsample_bytree':    [0.8, 1.0],
    'xgb__scale_pos_weight':    [ratio*0.5, ratio, ratio*1.5],
    'xgb__gamma':               [0, 0.1, 0.2],
    'xgb__reg_alpha':           [0.0, 0.01, 0.1],
    'xgb__reg_lambda':          [0.5, 1.0, 1.5],
    'xgb__min_child_weight':    [1, 3, 5],
}

param_grid_xgb_3 = {
    'xgb__n_estimators':     [150, 200, 250],
    'xgb__learning_rate':    [0.005, 0.01],
    'xgb__max_depth':        [5, 6, 7],
    'xgb__min_child_weight': [2, 6],
    'xgb__gamma':            [0.0, 0.1, 0.2, 0.3],
    'xgb__subsample':        [0.9, 1.0],
    'xgb__colsample_bytree': [1.0],
    'xgb__colsample_bylevel':[0.7, 1.0],
    'xgb__reg_alpha':        [0.0, 0.01, 0.05],
    'xgb__reg_lambda':       [0.5, 1.0, 2.0],
    'xgb__scale_pos_weight': [ratio*0.8, ratio, ratio*1.2],
}

param_grid_xgb_4 = {
    'xgb__n_estimators':     [150],
    'xgb__learning_rate':    [0.01],
    'xgb__max_depth':        [7],
    'xgb__min_child_weight': [2],
    'xgb__gamma':            [0.0],
    'xgb__subsample':        [1.0],
    'xgb__colsample_bytree': [1.0],
    'xgb__colsample_bylevel':[1.0],
    'xgb__reg_alpha':        [0.01],
    'xgb__reg_lambda':       [0.5],
    'xgb__scale_pos_weight': [ratio*0.8],
}

# %% [markdown]
# #### Entrenamiento y evaluación

# %%
from sklearn.pipeline import Pipeline


pipeline_xgb = ImbPipeline([
    ('scaler', StandardScaler()),
    ('under', RandomUnderSampler(sampling_strategy=0.3, random_state=42)),
    ('smt',   SMOTETomek(random_state=42)), 
    ('xgb', XGBClassifier(
        use_label_encoder=False,
        eval_metric='aucpr', #logloss
        scale_pos_weight=ratio,
        random_state=42
    ))
])

grid_search_xgb = GridSearchCV(estimator=pipeline_xgb, 
                            param_grid=param_grid_xgb_4,
                            scoring=scoring, 
                            refit='auc', 
                            cv= StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
                            n_jobs=5, 
                            verbose=2,  
                            return_train_score=True) 

grid_search_xgb.fit(x_data, y_data)

print("Mejores parámetros encontrados:", grid_search_xgb.best_params_)
print("Mejor puntuación:", grid_search_xgb.best_score_) 

# Exportar resultados
results_df = pd.DataFrame(grid_search_xgb.cv_results_)
results_df["auc_gap"] = results_df["mean_train_auc"] - results_df["mean_test_auc"]
results_df.to_csv("resultados/xgboost_gridsearch_results.csv", index=False, sep='|', decimal=',')

#Matriz de confusión:
# [[810 145]
# [  1  44]]
# 0.5611983711460151
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Mejores parámetros encontrados: {'xgb__colsample_bylevel': 1.0, 'xgb__colsample_bytree': 1.0, 'xgb__gamma': 0.0, 'xgb__learning_rate': 0.01, 'xgb__max_depth': 7, 'xgb__min_child_weight': 2, 'xgb__n_estimators': 150, 'xgb__reg_alpha': 0.01, 'xgb__reg_lambda': 0.5, 'xgb__scale_pos_weight': 16.977777777777778, 'xgb__subsample': 1.0}
# Mejor puntuación: 0.5611983711460151

# %% [markdown]
# #### Alternativa sin fuga de datos

# %%
# Calcula el peso
counts = Counter(y_data)
neg, pos = counts[0], counts[1]
ratio = neg / pos 
# Sin sampling, usar scale_pos_weight
param_grid_xgb_sw = {
    'xgb__booster': ['gbtree'],  # booster clásico
    'xgb__n_estimators': [300],
    'xgb__learning_rate': [0.05, 0.1],
    'xgb__max_depth': [3, 5],
    'xgb__min_child_weight': [3, 5],
    'xgb__subsample': [0.7, 1.0],
    'xgb__colsample_bytree': [0.6, 1.0],
    'xgb__colsample_bylevel': [0.6, 1.0],
    'xgb__gamma': [1.0],
    'xgb__reg_alpha': [0.1],
    'xgb__reg_lambda': [1.0],
    'xgb__scale_pos_weight': [ratio],
}

param_grid_xgb_sw2 = {
    'xgb__booster': ['gbtree'],  # booster clásico
    'xgb__n_estimators': [300, 500],
    'xgb__learning_rate': [0.05],
    'xgb__max_depth': [3, 4],
    'xgb__min_child_weight': [5],
    'xgb__subsample': [0.5, 0.7],
    'xgb__colsample_bytree': [0.6, 0.8],
    'xgb__colsample_bylevel': [0.6, 0.8],
    'xgb__gamma': [1.0],
    'xgb__reg_alpha': [0.01, 0.1],
    'xgb__reg_lambda': [0.8, 1.0],
    'xgb__scale_pos_weight': [ratio/2, ratio],
}

param_grid_xgb_smote = {
    'smote': [SMOTE(sampling_strategy=0.4, random_state=42, k_neighbors=3)],
    'xgb__booster': ['gbtree'],
    'xgb__n_estimators': [300, 500],
    'xgb__learning_rate': [0.05, 0.1],
    'xgb__max_depth': [3, 4],
    'xgb__min_child_weight': [5, 7, 10],
    'xgb__max_delta_step': [1],
    'xgb__subsample': [0.7, 1.0],
    'xgb__colsample_bytree': [0.4, 0.6],
    'xgb__colsample_bylevel': [0.4, 0.6],
    'xgb__gamma': [0.5, 1.0],
    'xgb__reg_alpha': [0.1, 0.5],
    'xgb__reg_lambda': [1.0, 2.0],
}

param_grid_xgb_min = {
    'xgb__booster': ['gbtree'],
    'xgb__learning_rate': [0.02, 0.05],
    'xgb__n_estimators': [200, 400],
    'xgb__max_depth': [2, 3],                 # MUY bajo
    'xgb__min_child_weight': [7, 10, 15],     # más alto = menos splits
    'xgb__max_delta_step': [1],               # estabiliza clases raras
    'xgb__subsample': [0.5, 0.7],
    'xgb__colsample_bytree': [0.3, 0.5],      # pocas features por árbol
    'xgb__colsample_bylevel': [0.3, 0.5],
    'xgb__gamma': [1.0, 2.0],                 # penaliza splits débiles
    'xgb__reg_alpha': [0.3, 1.0],             # L1 fuerte
    'xgb__reg_lambda': [2.0, 4.0],            # L2 fuerte
    'xgb__scale_pos_weight': [ratio/2, ratio, ratio*2],
}

# Los mejores resultados no generalizan bien, así que vamos a refinar
param_grid_xgb_min2 = {
    'xgb__booster': ['gbtree'],
    'xgb__learning_rate': [0.02, 0.05],
    'xgb__n_estimators': [400],
    'xgb__max_depth': [3],                 # MUY bajo
    'xgb__min_child_weight': [8, 10, 12],     # más alto = menos splits
    'xgb__max_delta_step': [1],               # estabiliza clases raras
    'xgb__subsample': [0.7],
    'xgb__colsample_bytree': [0.4, 0.5, 0.6],      # pocas features por árbol
    'xgb__colsample_bylevel': [0.4, 0.5, 0.6],
    'xgb__gamma': [0.5, 1.0],                 # penaliza splits débiles
    'xgb__reg_alpha': [0.6, 1.0],             # L1 fuerte
    'xgb__reg_lambda': [2.0, 3.0],            # L2 fuerte
    'xgb__scale_pos_weight': [ratio/3, ratio],
}

param_grid_xgb_min3 = {
    'xgb__booster': ['gbtree'],
    'xgb__learning_rate': [0.01, 0.02],
    'xgb__n_estimators': [400, 600],
    'xgb__max_depth': [3],                 # MUY bajo
    'xgb__min_child_weight': [10, 12, 15],     # más alto = menos splits
    'xgb__max_delta_step': [1],               # estabiliza clases raras
    'xgb__subsample': [0.7],
    'xgb__colsample_bytree': [0.4, 0.6],      # pocas features por árbol
    'xgb__colsample_bylevel': [0.4, 0.6],
    'xgb__gamma': [0.5, 0.8, 1],                 # penaliza splits débiles
    'xgb__reg_alpha': [0.6, 1, 1.5],             # L1 fuerte
    'xgb__reg_lambda': [2, 6.0],            # L2 fuerte
    'xgb__scale_pos_weight': [ratio/2, ratio/5, ratio],
}

#Selecccionando los mejores parámetros que si generalizan, quedan estos:
param_grid_xgb_refined = {
    'xgb__booster': ['gbtree'],
    'xgb__learning_rate': [0.02],
    'xgb__n_estimators': [400],
    'xgb__max_depth': [3],                  
    'xgb__min_child_weight': [10, 12],
    'xgb__max_delta_step': [1],
    'xgb__subsample': [0.7],
    'xgb__colsample_bytree': [0.4, 0.6],
    'xgb__colsample_bylevel': [0.5, 0.6],
    'xgb__gamma': [0.5, 1.0],
    'xgb__reg_alpha': [0.6, 1.0],
    'xgb__reg_lambda': [2.0], 
    'xgb__scale_pos_weight': [ratio/2, ratio/5, ratio/3, ratio/4],
}


param_grid_xgb_dart = {
  'xgb__booster': ['dart'],
  'xgb__learning_rate': [0.03],
  'xgb__n_estimators': [600],
  'xgb__max_depth': [3],
  'xgb__min_child_weight': [10, 12],
  'xgb__subsample': [0.7],
  'xgb__colsample_bytree': [0.4, 0.5],
  'xgb__colsample_bylevel': [0.4, 0.5],
  'xgb__gamma': [0.5, 1.0],
  'xgb__reg_alpha': [0.6, 1.0],
  'xgb__reg_lambda': [3.0, 4.0],
  'xgb__scale_pos_weight': [ratio],
  'xgb__rate_drop': [0.1, 0.2],
  'xgb__skip_drop': [0.0, 0.1],
  'xgb__sample_type': ['uniform', 'weighted'],
  'xgb__normalize_type': ['tree', 'forest'],
}

param_grid_xgb_tight = {
    'xgb__learning_rate': [0.02, 0.03],
    'xgb__n_estimators': [400, 550],
    'xgb__max_depth': [3],
    'xgb__min_child_weight': [10, 12],
    'xgb__max_delta_step': [1],
    'xgb__subsample': [0.7, 0.9],
    'xgb__colsample_bytree': [0.4, 0.5],
    'xgb__colsample_bylevel': [0.4, 0.5],
    'xgb__colsample_bynode': [0.5],     # NUEVO
    'xgb__gamma': [0.5, 1.0],
    'xgb__reg_alpha': [0.6, 1.0],
    'xgb__reg_lambda': [3.0, 4.0],
    'xgb__max_bin': [64],               # NUEVO
    # IMPORTANTE al usar RandomUnderSampler:
    'xgb__scale_pos_weight': [ratio], 
}

# %%
from sklearn.model_selection import GroupKFold

pipe_xgb = ImbPipeline(steps=[
    ('rare', RareCategoryGrouper(col='Category', min_freq=20)),   # NUEVO
    ('feat', FeatureEngineer(
        columns_to_drop=['TransactionID','Name','Age','Address'],
        ts_col='Timestamp', last_login_col='LastLogin',
        amount_col='TransactionAmount', balance_col='AccountBalance',
        category_col='Category',
        high_amount_q=0.75, add_hour_cyc=True, night_hours=(0,6)
    )),
    ('grp', GroupStatsByID(id_col='CustomerID', score_col='AnomalyScore', m=5.0)),  # NUEVO suavizado
    ('pre', pre),
    ('under', RandomUnderSampler(sampling_strategy=0.3, random_state=42)),    # seguro
    ('xgb', XGBClassifier(
        objective='binary:logistic',
        eval_metric='auc',
        tree_method='hist',
        max_bin=64,
        random_state=42,
        n_jobs=-1
    ))
])

grid_search_xgb = GridSearchCV(estimator=pipe_xgb, 
                            param_grid=param_grid_xgb_min3,
                            scoring=scoring, 
                            refit='auprc', 
                            cv= StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
                            n_jobs=-1, 
                            verbose=2,  
                            return_train_score=True) 

grid_search_xgb.fit(x_data_raw, y_data)

print("Mejores parámetros encontrados:", grid_search_xgb.best_params_)
print("Mejor puntuación:", grid_search_xgb.best_score_) 

# Exportar resultados
results_df = pd.DataFrame(grid_search_xgb.cv_results_)
results_df["auc_gap"] = results_df["mean_train_auc"] - results_df["mean_test_auc"]
results_df.to_csv("resultados/xgboost_gridsearch_results.csv", index=False, sep='|', decimal=',')


#Matriz de confusión:
## [[374 581]
# [  5  40]]
# Out:
# Fitting 5 folds for each of 2592 candidates, totalling 12960 fits
# Mejores parámetros encontrados: {'xgb__booster': 'gbtree', 'xgb__colsample_bylevel': 0.4, 'xgb__colsample_bytree': 0.4, 'xgb__gamma': 0.5, 'xgb__learning_rate': 0.01, 'xgb__max_delta_step': 1, 'xgb__max_depth': 3, 'xgb__min_child_weight': 15, 'xgb__n_estimators': 400, 'xgb__reg_alpha': 1.5, 'xgb__reg_lambda': 2, 'xgb__scale_pos_weight': 4.2444444444444445, 'xgb__subsample': 0.7}
# Mejor puntuación: 0.0829428164495791

# %%
results_df.to_csv("resultados/xgboost_gridsearch_results_param_grid_xgb_dart.csv")

# %% [markdown]
# #### otro

# %%
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from xgboost import XGBClassifier

pipe_xgb = ImbPipeline(steps=[
    ('rare', RareCategoryGrouper(col='Category', min_freq=20)),   # NUEVO
    ('feat', FeatureEngineer(
        columns_to_drop=['TransactionID','Name','Age','Address'],
        ts_col='Timestamp', last_login_col='LastLogin',
        amount_col='TransactionAmount', balance_col='AccountBalance',
        category_col='Category',
        high_amount_q=0.75, add_hour_cyc=True, night_hours=(0,6)
    )),
    ('grp', GroupStatsByID(id_col='CustomerID', score_col='AnomalyScore', m=5.0)),  # NUEVO suavizado
    ('pre', pre),
    ('under', RandomUnderSampler(sampling_strategy=0.3, random_state=42)),    # seguro
    ('xgb', XGBClassifier(
        objective='binary:logistic',
        eval_metric='auc',
        tree_method='hist',
        max_bin=64,
        random_state=42,
        n_jobs=-1
        # scale_pos_weight=1  (undersampling ya balancea)
    ))
])


grid_search_xgb = GridSearchCV(estimator=pipe_xgb, 
                            param_grid=param_grid_xgb_min2,
                            scoring=scoring, 
                            refit='auc', 
                            cv= StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
                            n_jobs=-1, 
                            verbose=2,  
                            return_train_score=True) 

grid_search_xgb.fit(x_data_raw, y_data)

print("Mejores parámetros encontrados:", grid_search_xgb.best_params_)
print("Mejor puntuación:", grid_search_xgb.best_score_) 

# Exportar resultados
results_df = pd.DataFrame(grid_search_xgb.cv_results_)
results_df["auc_gap"] = results_df["mean_train_auc"] - results_df["mean_test_auc"]
results_df.to_csv("resultados/xgboost_gridsearch_results.csv", index=False, sep='|', decimal=',')

#Matriz de confusión:
# [[865  90]
# [  0  45]]
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# Mejores parámetros encontrados: {'xgb__booster': 'gbtree', 'xgb__colsample_bylevel': 0.4, 'xgb__colsample_bytree': 0.5, 'xgb__gamma': 0.5, 'xgb__learning_rate': 0.05, 'xgb__max_delta_step': 1, 'xgb__max_depth': 3, 'xgb__min_child_weight': 8, 'xgb__n_estimators': 400, 'xgb__reg_alpha': 0.6, 'xgb__reg_lambda': 3.0, 'xgb__scale_pos_weight': 7.0740740740740735, 'xgb__subsample': 0.7}
# Mejor puntuación: 0.5511343804537521

# %% [markdown]
# #### otra

# %%
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from xgboost import XGBClassifier

pipe_xgb_under = ImbPipeline(steps=[
    ('feat', FeatureEngineer(
        columns_to_drop=['TransactionID','Name','Age','Address'],
        ts_col='Timestamp', last_login_col='LastLogin',
        amount_col='TransactionAmount', balance_col='AccountBalance',
        category_col='Category'
    )),
    ('grp', GroupStatsByID(id_col='CustomerID', score_col='AnomalyScore')),
    ('pre', pre),  # OHE + drop ids/timestamps
    ('under', RandomUnderSampler(sampling_strategy='majority', random_state=42)),
    ('xgb', XGBClassifier(
        objective='binary:logistic',
        eval_metric='auc',                 # te viene rindiendo mejor que aucpr
        tree_method='hist',
        max_bin=64,                        # NUEVO: suaviza y baja varianza
        random_state=42,
        n_jobs=-1
        # NOTA: SIN scale_pos_weight (dejalo en 1 por el undersampling)
    ))
])

param_grid_xgb_tight = {
    'xgb__learning_rate': [0.02, 0.03],
    'xgb__n_estimators': [400, 550],
    'xgb__max_depth': [3],
    'xgb__min_child_weight': [10, 12],
    'xgb__max_delta_step': [1],
    'xgb__subsample': [0.7, 0.9],
    'xgb__colsample_bytree': [0.4, 0.5],
    'xgb__colsample_bylevel': [0.4, 0.5],
    'xgb__colsample_bynode': [0.5],      # NUEVO
    'xgb__gamma': [0.5, 1.0],
    'xgb__reg_alpha': [0.6, 1.0],
    'xgb__reg_lambda': [3.0, 4.0],
}

from sklearn.model_selection import StratifiedKFold, GridSearchCV

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

scoring = {
    'auc': 'roc_auc',
    'auprc': 'average_precision',
    'recall': 'recall',
    'f1': 'f1'
}

grid_search_xgb = GridSearchCV(
    estimator=pipe_xgb_under,
    param_grid=param_grid_xgb_tight,
    scoring=scoring,
    refit='auc',          # te rinde mejor
    cv=cv,
    n_jobs=-1,
    verbose=2,
    return_train_score=True,
    error_score='raise'
)

grid_search_xgb.fit(x_data_raw, y_data)   # IMPORTANTE: sin groups=

print("Mejores parámetros encontrados:", grid_search_xgb.best_params_)
print("Mejor puntuación:", grid_search_xgb.best_score_) 

# Exportar resultados
results_df = pd.DataFrame(grid_search_xgb.cv_results_)
results_df["auc_gap"] = results_df["mean_train_auc"] - results_df["mean_test_auc"]
results_df.to_csv("resultados/xgboost_gridsearch_results.csv", index=False, sep='|', decimal=',')

results_df.to_csv("resultados/xgboost_gridsearch_results_param_grid_xgb_Estratificado.csv")

# 0.5
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# Mejores parámetros encontrados: {'xgb__colsample_bylevel': 0.4, 'xgb__colsample_bynode': 0.5, 'xgb__colsample_bytree': 0.4, 'xgb__gamma': 0.5, 'xgb__learning_rate': 0.02, 'xgb__max_delta_step': 1, 'xgb__max_depth': 3, 'xgb__min_child_weight': 10, 'xgb__n_estimators': 400, 'xgb__reg_alpha': 0.6, 'xgb__reg_lambda': 3.0, 'xgb__subsample': 0.7}
# Mejor puntuación: 0.5

# %% [markdown]
# #### Validacion de importancia de variables

# %%
import matplotlib.pyplot as plt
best_pipeline = grid_search_xgb.best_estimator_

importances = best_pipeline.named_steps['xgb'].feature_importances_
features = x_data_raw.columns 
sorted_idx = importances.argsort()

plt.figure(figsize=(6,6))
plt.barh(range(len(features)), importances[sorted_idx])
plt.yticks(range(len(features)), features[sorted_idx])
plt.xlabel("Importancia")
plt.title("Importancia de las variables - XGBoost")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 9
#       6 sorted_idx = importances.argsort()
#       8 plt.figure(figsize=(6,6))
# ----> 9 plt.barh(range(len(features)), importances[sorted_idx])
#      10 plt.yticks(range(len(features)), features[sorted_idx])
#      11 plt.xlabel("Importancia")
#
# File c:\Users\camil\OneDrive\Escritorio\Tesis\proyectos\main\.venv\Lib\site-packages\matplotlib\pyplot.py:3019, in barh(y, width, height, left, align, data, **kwargs)
#    3008 @_copy_docstring_and_deprecators(Axes.barh)
#    3009 def barh(
#    3010     y: float | ArrayLike,
#    (...)   3017     **kwargs,
#    3018 ) -> BarContainer:
# -> 3019     return gca().barh(
#    3020         y,
#    3021         width,
#    3022         height=height,
#    3023         left=left,
#    3024         align=align,
# ...

# %% [markdown]
# #### Ajuste del Umbral de Clasificación

# %%
# Después del fit
y_scores = grid_search_xgb.predict_proba(x_data_raw)[:, 1]
prec, rec, thresholds = precision_recall_curve(y_data, y_scores)

# Plot para elegir punto de corte
plt.plot(thresholds, prec[:-1], label='Precision')
plt.plot(thresholds, rec[:-1], label='Recall')
plt.xlabel('Threshold')
plt.legend()
plt.grid()
plt.show()

# %%
# Obtener el mejor pipeline entrenado
best_pipeline = grid_search_xgb.best_estimator_

y_proba = best_pipeline.predict_proba(x_data_raw)[:, 1]  # Probabilidad de clase 1

y_pred = (y_proba >= 0.75).astype(int)

print("Matriz de confusión:\n", confusion_matrix(y_data, y_pred))
print("\nReporte de clasificación:\n", classification_report(y_data, y_pred, digits=4))
print("AUC:", roc_auc_score(y_data, y_proba))


# Calcula la curva ROC
fpr, tpr, thresholds = roc_curve(y_data, y_proba)
roc_auc = auc(fpr, tpr)

# Plot
print("Curva ROC:\n")
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Matriz de confusión:
#  [[865  90]
#  [  0  45]]
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.9058    0.9505       955
#            1     0.3333    1.0000    0.5000        45
#
#     accuracy                         0.9100      1000
#    macro avg     0.6667    0.9529    0.7253      1000
# weighted avg     0.9700    0.9100    0.9303      1000
#
# AUC: 0.9676556137289122
# Curva ROC:

# %% [markdown]
# ## Red Neuronal

# %% [markdown]
# Se define la clase MyKerasClassifier para reemplazar a KerasClassifier,
# debido a que en versiones recientes de scikit-learn (≥0.24) y TensorFlow (≥2.6),
# este último presenta problemas de compatibilidad: no implementa correctamente
# el método score() y sus predicciones pueden no ser compatibles con métricas
# como F1, precisión y recall. Esto impide que GridSearchCV calcule correctamente
# los resultados cuando se utilizan múltiples métricas. Al definir un estimador
# personalizado compatible con la API de scikit-learn, se garantiza el funcionamiento
# correcto dentro del pipeline y del proceso de validación cruzada.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LeakyReLU, Input
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import metrics, optimizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.class_weight import compute_class_weight
import numpy as np, tensorflow as tf, random

class MyKerasClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, hidden_layers=[(64, 'relu')], dropout_rate=0.0, optimizer='adam',
                 output_activation='sigmoid', epochs=10, batch_size=32, verbose=0,
                 regularizer=None, regularizer_strength=0.01, random_state=None,
                 class_weight='balanced',              # <- NUEVO
                 early_stopping=True, patience=5,      # <- opcional
                 val_split=0.1,                        # <- opcional
                 loss_type='bce',                      # <- 'bce' o 'focal' (ver sección B)
                 focal_gamma=2.0, focal_alpha=0.25):   # <- para focal loss
        self.hidden_layers = hidden_layers
        self.dropout_rate = dropout_rate
        self.optimizer = optimizer
        self.output_activation = output_activation
        self.epochs = epochs
        self.batch_size = batch_size
        self.verbose = verbose
        self.regularizer = regularizer
        self.regularizer_strength = regularizer_strength
        self.random_state = random_state
        self.class_weight = class_weight
        self.early_stopping = early_stopping
        self.patience = patience
        self.val_split = val_split
        self.loss_type = loss_type
        self.focal_gamma = focal_gamma
        self.focal_alpha = focal_alpha
        self.model_ = None

    def _set_seed(self):
        if self.random_state is not None:
            np.random.seed(self.random_state)
            random.seed(self.random_state)
            tf.random.set_seed(self.random_state)

    def _get_regularizer(self):
        if self.regularizer == 'l1':
            return l1(self.regularizer_strength)
        elif self.regularizer == 'l2':
            return l2(self.regularizer_strength)
        elif self.regularizer == 'l1_l2':
            return l1_l2(self.regularizer_strength)
        else:
            return None

    # --- Focal loss nativa (evita dependencias externas) ---
    def _binary_focal_loss(self, gamma=2.0, alpha=0.25):
        def loss(y_true, y_pred):
            y_true = tf.cast(y_true, tf.float32)
            eps = tf.keras.backend.epsilon()
            y_pred = tf.clip_by_value(y_pred, eps, 1. - eps)
            pt = tf.where(tf.equal(y_true, 1.), y_pred, 1. - y_pred)
            w = tf.where(tf.equal(y_true, 1.), alpha, 1. - alpha)
            return -tf.reduce_mean(w * tf.pow(1. - pt, gamma) * tf.math.log(pt))
        return loss

    def _get_loss(self):
        if self.loss_type == 'focal':
            return self._binary_focal_loss(self.focal_gamma, self.focal_alpha)
        return 'binary_crossentropy'

    def _get_optimizer(self):
        return optimizers.get(self.optimizer)

    def build_model(self, input_dim):
        model = Sequential()
        model.add(Input(shape=(input_dim,)))
        reg = self._get_regularizer()
        for units, activation in self.hidden_layers:
            if activation == 'leaky_relu':
                model.add(Dense(units, kernel_regularizer=reg))
                model.add(LeakyReLU(alpha=0.01))
            else:
                model.add(Dense(units, activation=activation, kernel_regularizer=reg))
            model.add(Dropout(self.dropout_rate))
        model.add(Dense(1, activation=self.output_activation))
        model.compile(
            loss=self._get_loss(),
            optimizer=self._get_optimizer(),
            metrics=[metrics.AUC(name='auc'),
                     metrics.AUC(curve='PR', name='auprc')]
        )
        return model

    def fit(self, X, y):
        self._set_seed()
        self.model_ = self.build_model(X.shape[1])

        # class_weight calculado SOLO con y del fold (sin fuga)
        cw = None
        if self.class_weight == 'balanced':
            classes = np.unique(y)
            weights = compute_class_weight('balanced', classes=classes, y=y)
            cw = {int(c): float(w) for c, w in zip(classes, weights)}
        elif isinstance(self.class_weight, dict):
            cw = self.class_weight

        callbacks = []
        if self.early_stopping and self.val_split and self.val_split > 0:
            callbacks.append(EarlyStopping(monitor='val_auc', mode='max',
                                           patience=self.patience, restore_best_weights=True))

        self.model_.fit(
            X, y,
            epochs=self.epochs,
            batch_size=self.batch_size,
            verbose=self.verbose,
            validation_split=self.val_split if self.val_split > 0 else 0.0,
            class_weight=cw,
            callbacks=callbacks
        )
        return self

    def predict_proba(self, X):
        p = self.model_.predict(X, verbose=0).ravel()
        return np.vstack([1 - p, p]).T

    def predict(self, X):
        p = self.predict_proba(X)[:, 1]
        return (p >= 0.5).astype(int)

    def score(self, X, y):
        from sklearn.metrics import roc_auc_score
        return roc_auc_score(y, self.predict_proba(X)[:,1])

# %% [markdown]
# #### Definición de parametros

# %%
#definir scaler
param_grid_0 = {
    #'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler()], #MinMaxScaler(), RobustScaler()]
    #'under': [RandomUnderSampler(sampling_strategy=0.3, random_state=42)],
    #'smote': [SMOTE(random_state=42),  SVMSMOTE(random_state=42), ADASYN(random_state=42), SMOTETomek(random_state=42)],
    'clf__batch_size': [32],
    'clf__epochs': [50],  
    'clf__dropout_rate': [0.2, 0.3, 0.4],
    'clf__regularizer': ['l2', 'l1_l2'],
    'clf__regularizer_strength': [1e-4, 1e-3],
    'clf__optimizer': ['adam'],
    'clf__loss_type': ['bce', 'focal'],
    'clf__focal_gamma': [2.0],      # solo si 'focal'
    'clf__focal_alpha': [0.25],     # solo si 'focal'
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': ['balanced', None],  # probá ambos
    'clf__hidden_layers': [
        [(64,'relu'), (32,'relu')],
        [(64,'selu'), (32,'selu')],
        [(32,'elu'),  (64,'elu')],
    ],
    'clf__output_activation': ['sigmoid']
}

param_grid_nn_refined = {
    # arquitectura: pequeñas variantes alrededor de (32, ELU) -> (64, ELU)
    'clf__hidden_layers': [
        [(32,'elu'), (64,'elu')],               # 
        [(32,'elu'), (64,'elu'), (32,'elu')],   
        [(64,'elu'), (64,'elu')],               
    ],

    # regularización: alrededor de l1_l2=1e-4
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [1e-5, 1e-4, 3e-4],  #1e-5, 1e-4

    # dropout cerca de 0.4
    'clf__dropout_rate': [0.40, 0.45], # 0.40

    # focal loss afinada
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20, 0.25, 0.30], #0.2
    'clf__focal_gamma': [1.5, 2.0, 2.5], # 2

    # entrenamiento
    'clf__batch_size': [32],        # tu mejor fue 32; probamos 64 por estabilidad
    'clf__epochs': [60],                # con early stopping, puede cortar antes
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],        # tu mejor fue sin class_weight
    'clf__output_activation': ['sigmoid'],
}

param_grid_nn_bce_small = {
    'clf__hidden_layers': [
        [(32,'elu'), (64,'elu')],
        [(64,'relu'), (32,'relu')],     # tu otra config “decente”
    ],
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [1e-4, 1e-3],
    'clf__dropout_rate': [0.4],
    'clf__loss_type': ['bce'],
    'clf__batch_size': [32],
    'clf__epochs': [60],
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],
    'clf__output_activation': ['sigmoid'],
}


#definir under y smote
param_grid_1 = {
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [1e-5, 1e-4],  #1e-5, 1e-4

    # dropout cerca de 0.4
    'clf__dropout_rate': [0.40], # 0.40

    # focal loss afinada
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20], #0.2
    'clf__focal_gamma': [2.0], # 2

    # entrenamiento
    'clf__batch_size': [32],        # tu mejor fue 32; probamos 64 por estabilidad
    'clf__epochs': [60],                # con early stopping, puede cortar antes
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],        # tu mejor fue sin class_weight
    'clf__hidden_layers': [
        [(32, 'relu')], 
        [(32, 'tanh')],
        [(32, 'leaky_relu')], 
        [(32, 'elu')], 
        [(32, 'prelu')], 
        [(32, 'elu')], #
        [(64, 'relu')],
        [(64, 'tanh')], #
        [(64, 'leaky_relu')],
        [(64, 'elu')],
        [(64, 'prelu')], 
        [(64, 'selu')], 
        [(128, 'relu')],
        [(128, 'tanh')],
        [(128, 'leaky_relu')],
        [(128, 'selu')], 
        [(128, 'prelu')], 
    ],
    'clf__output_activation': ['sigmoid']
}

# probar distintas capas ocultas y activaciones
param_grid_2 = {
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [1e-5, 1e-4],  #1e-5, 1e-4

    # dropout cerca de 0.4
    'clf__dropout_rate': [0.40], # 0.40

    # focal loss afinada
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20], #0.2
    'clf__focal_gamma': [2.0], # 2

    # entrenamiento
    'clf__batch_size': [32],        # tu mejor fue 32; probamos 64 por estabilidad
    'clf__epochs': [60],                # con early stopping, puede cortar antes
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],        # tu mejor fue sin class_weight
    'clf__hidden_layers': [
        [(32, 'selu')], # 
        [(32, 'tanh')],

        [(32, 'selu'), (32, 'selu')],
        [(32, 'selu'), (64, 'selu')],
        [(64, 'selu'), (64, 'selu')],
        [(64, 'selu'), (128, 'selu')], 
        [(128, 'selu'), (64, 'selu')], 
        [(128, 'selu'), (128, 'selu')],
        
        [(32, 'tanh'), (32, 'tanh')],
        [(32, 'tanh'), (64, 'tanh')],
        [(64, 'tanh'), (64, 'tanh')],
        [(64, 'tanh'), (128, 'tanh')], 
        [(128, 'tanh'), (64, 'tanh')], 
        [(128, 'tanh'), (128, 'tanh')],
        
        [(32, 'selu'), (32, 'tanh')],
        [(32, 'selu'), (64, 'tanh')],
        [(64, 'selu'), (64, 'tanh')],
        [(64, 'selu'), (128, 'tanh')], 
        [(128, 'selu'), (64, 'tanh')], 
        [(128, 'selu'), (128, 'tanh')],
        
        [(32, 'selu'), (32, 'tanh')],
        [(32, 'selu'), (64, 'tanh')],
        [(64, 'selu'), (64, 'tanh')],
        [(64, 'selu'), (128, 'tanh')], 
        [(128, 'selu'), (64, 'tanh')], 
        [(128, 'selu'), (128, 'tanh')],

    ],
    'clf__output_activation': ['sigmoid']
}
# con mejores opciones
param_grid_3 = {
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [1e-4],  #1e-5, 1e-4

    # dropout cerca de 0.4
    'clf__dropout_rate': [0.40], # 0.40

    # focal loss afinada
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20], #0.2
    'clf__focal_gamma': [2.0], # 2

    # entrenamiento
    'clf__batch_size': [32],        # tu mejor fue 32; probamos 64 por estabilidad
    'clf__epochs': [60],                # con early stopping, puede cortar antes
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],        # tu mejor fue sin class_weight
    'clf__hidden_layers': [
        [(128, 'tanh'), (64, 'tanh')],

        [(32, 'tanh'), (32, 'tanh'), (32, 'tanh')],
        [(64, 'tanh'), (32, 'tanh'), (32, 'tanh')],
        [(64, 'tanh'), (64, 'tanh'), (32, 'tanh')],
        [(64, 'tanh'), (64, 'tanh'), (64, 'tanh')],
        [(128, 'tanh'), (64, 'tanh'), (64, 'tanh')],
        [(128, 'tanh'), (128, 'tanh'), (64, 'tanh')],
        [(128, 'tanh'), (128, 'tanh'), (128, 'tanh')],
        [(32, 'tanh'), (128, 'tanh'), (64, 'tanh')],
        [(128, 'tanh'), (64, 'tanh'), (32, 'tanh')],
        [(128, 'tanh'), (32, 'tanh'), (32, 'tanh')],
        
        [(32, 'selu'), (32, 'selu'), (32, 'selu')],
        [(64, 'selu'), (32, 'selu'), (32, 'selu')],
        [(64, 'selu'), (64, 'selu'), (32, 'selu')],
        [(64, 'selu'), (64, 'selu'), (64, 'selu')],
        [(128, 'selu'), (64, 'selu'), (64, 'selu')],
        [(128, 'selu'), (128, 'selu'), (64, 'selu')],
        [(128, 'selu'), (128, 'selu'), (128, 'selu')],
        [(32, 'selu'), (128, 'selu'), (64, 'selu')],
        [(128, 'selu'), (64, 'selu'), (32, 'selu')],
        [(128, 'selu'), (32, 'selu'), (32, 'selu')],
        
        [(32, 'selu'), (32, 'selu'), (32, 'tanh')],
        [(64, 'selu'), (32, 'selu'), (32, 'tanh')],
        [(64, 'selu'), (64, 'selu'), (32, 'tanh')],
        [(64, 'selu'), (64, 'selu'), (64, 'tanh')],
        [(128, 'selu'), (64, 'selu'), (64, 'tanh')],
        [(128, 'selu'), (128, 'selu'), (64, 'tanh')],
        [(128, 'selu'), (128, 'selu'), (128, 'tanh')],
        [(32, 'selu'), (128, 'selu'), (64, 'tanh')],
        [(128, 'selu'), (64, 'selu'), (32, 'tanh')],
        [(128, 'selu'), (32, 'selu'), (32, 'tanh')],
        
        [(32, 'selu'), (32, 'tanh'), (32, 'selu')],
        [(64, 'selu'), (32, 'tanh'), (32, 'selu')],
        [(64, 'selu'), (64, 'tanh'), (32, 'selu')],
        [(64, 'selu'), (64, 'tanh'), (64, 'selu')],
        [(128, 'selu'), (64, 'tanh'), (64, 'selu')],
        [(128, 'selu'), (128, 'tanh'), (64, 'selu')],
        [(128, 'selu'), (128, 'tanh'), (128, 'selu')],
        [(32, 'selu'), (128, 'tanh'), (64, 'selu')],
        [(128, 'selu'), (64, 'tanh'), (32, 'selu')],
        [(128, 'selu'), (32, 'tanh'), (32, 'selu')],
        
        [(32, 'selu'), (32, 'tanh'), (32, 'tanh')],
        [(64, 'selu'), (32, 'tanh'), (32, 'tanh')],
        [(64, 'selu'), (64, 'tanh'), (32, 'tanh')],
        [(64, 'selu'), (64, 'tanh'), (64, 'tanh')],
        [(128, 'selu'), (64, 'tanh'), (64, 'tanh')],
        [(128, 'selu'), (128, 'tanh'), (64, 'tanh')],
        [(128, 'selu'), (128, 'tanh'), (128, 'tanh')],
        [(32, 'selu'), (128, 'tanh'), (64, 'tanh')],
        [(128, 'selu'), (64, 'tanh'), (32, 'tanh')],
        [(128, 'selu'), (32, 'tanh'), (32, 'tanh')],
    ],
    'clf__output_activation': ['sigmoid']
}

# buem resultado pero con menos generalización
param_grid_4 = {
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [1e-4],  #1e-5, 1e-4

    # dropout cerca de 0.4
    'clf__dropout_rate': [0.40], # 0.40

    # focal loss afinada
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20], #0.2
    'clf__focal_gamma': [2.0], # 2

    # entrenamiento
    'clf__batch_size': [32],       
    'clf__epochs': [60],         
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],       
    'clf__hidden_layers': [
        [(128, 'tanh'), (64, 'tanh')],
    ],
    'clf__output_activation': ['sigmoid']
}

# cambiar regularizer_strength y hidden_layers
param_grid_5 = {
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [5e-5, 1e-4, 3e-4],   # un poco abajo/arriba

    # dropout alrededor de 0.4
    'clf__dropout_rate': [0.35, 0.40, 0.45],

    # focal loss afinada
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20], #0.2
    'clf__focal_gamma': [2.0], # 2

    # entrenamiento
    'clf__batch_size': [32, 64],      # 32 fue tu mejor, 64 puede mejorar gral.
    'clf__epochs': [70],              # +10, con early_stopping se corta antes
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],

    # arquitecturas variantes alrededor de (128,tanh)->(64,tanh)
    'clf__hidden_layers': [
        [(128, 'tanh'), (64, 'tanh')],              # tu mejor
        [(64, 'tanh'), (64, 'tanh')],               # menos capacidad
    ],

    'clf__output_activation': ['sigmoid'],
}

param_grid_buenageneralizacion = {
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [3e-4],
    'clf__dropout_rate': [0.4],
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20], 
    'clf__focal_gamma': [2.0], 
    'clf__batch_size': [64],     
    'clf__epochs': [70],            
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],
    'clf__hidden_layers': [
        [(64, 'tanh'), (64, 'tanh')]       
    ],
    'clf__output_activation': ['sigmoid'],
}

param_grid_conmenosgeneralizacion = {
    'clf__regularizer': ['l1_l2'],
    'clf__regularizer_strength': [1e-4],
    'clf__dropout_rate': [0.45],
    'clf__loss_type': ['focal'],
    'clf__focal_alpha': [0.20], 
    'clf__focal_gamma': [2.0], 
    'clf__batch_size': [32],     
    'clf__epochs': [70],            
    'clf__optimizer': ['adam'],
    'clf__val_split': [0.1],
    'clf__early_stopping': [True],
    'clf__class_weight': [None],
    'clf__hidden_layers': [
        [(128, 'tanh'), (64, 'tanh')]       
    ],
    'clf__output_activation': ['sigmoid'],
}

# %% [markdown]
# ### Entrenamiento y evaluación

# %%
from sklearn.preprocessing import FunctionTransformer
pipeline = ImbPipeline(steps=[
    ('rare', RareCategoryGrouper(col='Category', min_freq=20)),
    ('feat', FeatureEngineer(
        columns_to_drop=['TransactionID','Name','Age','Address'],
        ts_col='Timestamp', last_login_col='LastLogin',
        amount_col='TransactionAmount', balance_col='AccountBalance',
        category_col='Category', high_amount_q=0.75,
        add_hour_cyc=True, night_hours=(0,6)
    )),
    ('grp', GroupStatsByID(id_col='CustomerID', score_col='AnomalyScore', m=5.0)), 
    ('cust_hist', HistoryByID(id_col='CustomerID', ts_col='Timestamp',
                              amount_col='TransactionAmount', m=10.0, prefix='cust')),
    ('mch_hist', HistoryByID(id_col='MerchantID', ts_col='Timestamp',
                             amount_col='TransactionAmount', m=10.0, prefix='mch')),
    ('pair_hist', PairHistory(cust_col='CustomerID', merch_col='MerchantID',
                              ts_col='Timestamp', prefix='pair')),
    ('cat_te', TargetMeanEncoder(col='Category', m=10.0)),
    ('pre', pre),
    ('astype', FunctionTransformer(lambda X: X.astype('float32'))),
    ('clf', MyKerasClassifier(epochs=50, random_state=42, early_stopping=True, patience=5, val_split=0.1,
        loss_type='bce'  # <- BCE por defecto
    ))
])

grid_search = GridSearchCV(
    estimator = pipeline,
    param_grid = param_grid_5,
    scoring = scoring,
    refit = 'auc',  
    cv = cv,
    verbose=2,
    n_jobs=-1,
    return_train_score=True
)

grid_search.fit(x_data_raw, y_data)

print("Mejores parámetros encontrados:", grid_search.best_params_)
print("Mejor puntuación:", grid_search.best_score_) 

# Exportar resultados
results_df = pd.DataFrame(grid_search.cv_results_)
results_df["auc_gap"] = results_df["mean_train_auc"] - results_df["mean_test_auc"]
results_df.to_csv("resultados/red_neuronal_grid_search.csv", index=False, sep='|', decimal=',')

# Mejor puntuación: 0.557998836532868
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Mejores parámetros encontrados: {'clf__batch_size': 32, 'clf__class_weight': None, 'clf__dropout_rate': 0.45, 'clf__early_stopping': True, 'clf__epochs': 70, 'clf__focal_alpha': 0.2, 'clf__focal_gamma': 2.0, 'clf__hidden_layers': [(128, 'tanh'), (64, 'tanh')], 'clf__loss_type': 'focal', 'clf__optimizer': 'adam', 'clf__output_activation': 'sigmoid', 'clf__regularizer': 'l1_l2', 'clf__regularizer_strength': 0.0001, 'clf__val_split': 0.1}
# Mejor puntuación: 0.5848749272833043

# %%
results_df.to_csv("resultados/red_neuronal_grid_search_.csv", index=False)

# %% [markdown]
# ### Ajuste del Umbral de Clasificación

# %%
# Después del fit
y_scores = grid_search.predict_proba(x_data_raw)[:, 1]
prec, rec, thresholds = precision_recall_curve(y_data, y_scores)

# Plot para elegir punto de corte
plt.plot(thresholds, prec[:-1], label='Precision')
plt.plot(thresholds, rec[:-1], label='Recall')
plt.xlabel('Threshold')
plt.legend()
plt.grid()
plt.show()

# %%
# Obtener el mejor pipeline entrenado
best_pipeline = grid_search.best_estimator_

y_proba = best_pipeline.predict_proba(x_data_raw)[:, 1]  # Probabilidad de clase 1

y_pred = (y_proba >= 0.23).astype(int)

print("Umbral de clasificacion: ", 0.258)
print("Matriz de confusión:\n", confusion_matrix(y_data, y_pred))
print("\nReporte de clasificación:\n", classification_report(y_data, y_pred, digits=4))
print("AUC:", roc_auc_score(y_data, y_proba))


# Calcula la curva ROC
fpr, tpr, thresholds = roc_curve(y_data, y_proba)
roc_auc = auc(fpr, tpr)

# Plot
print("Curva ROC:\n")
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Umbral de clasificacion:  0.258
# Matriz de confusión:
#  [[942  13]
#  [  0  45]]
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.9864    0.9931       955
#            1     0.7759    1.0000    0.8738        45
#
#     accuracy                         0.9870      1000
#    macro avg     0.8879    0.9932    0.9335      1000
# weighted avg     0.9899    0.9870    0.9878      1000
#
# AUC: 0.9991855730075626
# Curva ROC:

# %% [markdown]
# #### viejo

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from imblearn.under_sampling import RandomUnderSampler
pipeline = Pipeline([
    ('scaler', StandardScaler()), 
    ('under', RandomUnderSampler(sampling_strategy=0.3, random_state=42)),
    ('smote', SMOTE(random_state=42)),
    ('clf', MyKerasClassifier(epochs=50, random_state=42))
])

grid = GridSearchCV(
    estimator = pipeline,
    param_grid = param_grid_5,
    scoring = scoring,
    refit = 'auc',  
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    verbose=2,
    n_jobs=-1,
    return_train_score=True
)
# Ejecutar búsqueda 
grid_result = grid.fit(x_data, y_data)

# Guardar resultados
results_df = pd.DataFrame(grid_result.cv_results_)
results_df.to_csv("resultados/red_neuronal_grid_search.csv", index=False, sep='|', decimal=',')

# Mejor resultado
print("Mejor: %.4f usando %s" % (grid_result.best_score_, grid_result.best_params_))

# %% [markdown]
# # Guardado en MLFlow de mejor modelo

# %%
CARGA_MFLOW = False

# %%
if CARGA_MFLOW:
    mlflow.set_tracking_uri("http://localhost:8080")
    mlflow.set_experiment("Detección de fraude electrónico")

# %%
if CARGA_MFLOW:
    with mlflow.start_run(run_name="XGBoost_Best_Model_GridSearch"):
        # 1. Registrar los hiperparámetros del mejor modelo
        mlflow.log_params(grid_search_xgb.best_params_)
        mlflow.log_param("threshold", 0.7)


        # 2. Registrar las métricas del mejor modelo
        best_index = grid_search_xgb.best_index_
        metrics_to_log = {}
        for score_name in scoring.keys():
            metric_col = f'mean_test_{score_name}'
            metrics_to_log[score_name] = grid_search_xgb.cv_results_[metric_col][best_index]
        
        mlflow.log_metrics(metrics_to_log)

        # 3. Guardar curva ROC para el mejor modelo
        mlflow.log_artifact("./services/mlflow/figures/roc_curve_xgboost.png")

        # 3. Crea un ejemplo de entrada utilizando tus datos (x_data)
        input_example_for_mlflow = x_data.sample(n=5, random_state=42) if isinstance(x_data, pd.DataFrame) else x_data[:5]

        # 4. Inferir la firma del modelo
        signature = infer_signature(input_example_for_mlflow, grid_search_xgb.best_estimator_.predict(input_example_for_mlflow))

        # 5. Guardar el mejor modelo
        mlflow.sklearn.log_model(
            sk_model=grid_search_xgb.best_estimator_,
            artifact_path="model", 
            registered_model_name="XGBoostModel",
            signature=signature,
            input_example=input_example_for_mlflow
        )

        print("\n--- MLflow ---")
        print(f"Modelo y métricas registrados en MLflow con Run ID: {mlflow.active_run().info.run_id}")
        print(f"Para ver los resultados, ejecuta 'mlflow ui' en tu terminal.")

# %%
from sklearn.model_selection import cross_validate

# Configuración final de los hiperparámetros de Regresión Logística
final_lr_params = {
    'clf__penalty': 'l2',
    'clf__C': 0.01,
    'clf__solver': 'lbfgs',
    'clf__class_weight': 'balanced', 
    'clf__max_iter': 100,
    'clf__fit_intercept': True,
    'clf__tol': 0.0001
}

# Aplicar los parámetros directamente al pipeline
pipeline_lr.set_params(**final_lr_params)

cv_results_final_model = cross_validate(
    pipeline_lr,
    x_data,
    y_data,
    scoring=scoring,
    cv=skf_lr,
    return_train_score=False, 
    n_jobs=-1
)

# Calcula las medias de las métricas de validación
mean_metrics_final = {
    score_name: np.mean(cv_results_final_model[f'test_{score_name}'])
    for score_name in scoring.keys()
}

# Entrenar el modelo final en todo el conjunto de datos para poder guardarlo y usarlo para predicciones
final_model = pipeline_lr.fit(x_data, y_data)

# Registro en MLflow
if CARGA_MFLOW:
    with mlflow.start_run(run_name="Logistic_Regression_Final_Model_run"):
        # 1. Registrar los hiperparámetros del modelo final
        mlflow.log_params(final_lr_params)

        # 2. Registrar las métricas del modelo final (promedio de CV)
        mlflow.log_metrics(mean_metrics_final)

        # 3. Calcular y graficar la Curva ROC para el modelo final entrenado
        y_pred_proba = final_model.predict_proba(x_data)[:, 1]  # Probabilidad de la clase positiva

        fpr, tpr, thresholds = roc_curve(y_data, y_pred_proba)
        best_auc = roc_auc_score(y_data, y_pred_proba)

        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, label=f"ROC del Modelo Final (AUC = {best_auc:.3f})")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Línea Aleatoria')
        plt.xlabel("Tasa de Falsos Positivos (FPR)")
        plt.ylabel("Tasa de Verdaderos Positivos (TPR)")
        plt.title("Curva ROC del Modelo Final de Regresión Logística")
        plt.legend(fontsize="medium")
        plt.grid(True)
        plt.tight_layout()

        # Si quieres guardar la figura en un archivo y loggearla en MLflow
        plt.savefig("./services/mlflow/figures/roc_curve_final_model.png")
        mlflow.log_artifact("./services/mlflow/figures/roc_curve_final_model.png")
        plt.close()

        # 4. Crea un ejemplo de entrada utilizando tus datos (x_data)
        input_example_for_mlflow = x_data.sample(n=5, random_state=42) if isinstance(x_data, pd.DataFrame) else x_data[:5]

        # 5. Inferir la firma del modelo
        signature = infer_signature(input_example_for_mlflow, final_model.predict(input_example_for_mlflow))

        # 6. Guardar el modelo final
        mlflow.sklearn.log_model(
            sk_model=final_model,
            artifact_path="models",
            registered_model_name="LogisticRegression_Model",
            signature=signature,
            input_example=input_example_for_mlflow
        )

        print("\n--- MLflow ---")
        print(f"Modelo y métricas registrados en MLflow con Run ID: {mlflow.active_run().info.run_id}")
        print(f"Para ver los resultados, ejecuta 'mlflow ui' en tu terminal.")
